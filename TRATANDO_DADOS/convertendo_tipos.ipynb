# %%
import pandas as pd

# %%
df = pd.read_csv("../data/customers.csv", sep=";")
df
# Out:
#                                      UUID              Name Points
# 0    aa3eaf74-6d9c-4859-b733-5a18a3b2f71b         afonso_rf    792
# 1    2d3d2dce-d353-4961-ad39-46723efe2100     mariicmartins   1375
# 2    ca95ef2a-5129-40f4-acbc-2ced25940032           tdlupus    421
# 3    65662aff-44d6-4f06-b9d9-07445c6e5943            kozat0   4063
# 4    98b960e7-6b7b-45b7-b7af-60bca40e04b9            gu1z17      0
# ..                                    ...               ...    ...
# 786  4a36c617-b018-436a-babc-4374461ab87b         null__var     53
# 787  403db18e-941e-4e63-ba23-e63c0515876a         lmadriles     50
# 788  c9bfbbf9-db90-45a7-a72c-4118140038f4  eduardo_cofferri     50
# 789  4caa2fb3-7ed2-436d-bc35-390feebfdebe          marmschu     50
# 790  000ff655-fa9f-4baa-a108-47f581ec52a1            cajuuh     52
#
# [791 rows x 3 columns]

# %%
df.dtypes
# Out:
# UUID      object
# Name      object
# Points    object
# dtype: object

# %%
df["Points_dobble"] = df["Points"] * 2
df
# Out:
#                                      UUID              Name Points  \
# 0    aa3eaf74-6d9c-4859-b733-5a18a3b2f71b         afonso_rf    792
# 1    2d3d2dce-d353-4961-ad39-46723efe2100     mariicmartins   1375
# 2    ca95ef2a-5129-40f4-acbc-2ced25940032           tdlupus    421
# 3    65662aff-44d6-4f06-b9d9-07445c6e5943            kozat0   4063
# 4    98b960e7-6b7b-45b7-b7af-60bca40e04b9            gu1z17      0
# ..                                    ...               ...    ...
# 786  4a36c617-b018-436a-babc-4374461ab87b         null__var     53
# 787  403db18e-941e-4e63-ba23-e63c0515876a         lmadriles     50
# 788  c9bfbbf9-db90-45a7-a72c-4118140038f4  eduardo_cofferri     50
# 789  4caa2fb3-7ed2-436d-bc35-390feebfdebe          marmschu     50
# 790  000ff655-fa9f-4baa-a108-47f581ec52a1            cajuuh     52
#
#     Points_dobble
# 0          792792
# 1        13751375
# 2          421421
# 3        40634063
# 4              00
# ..            ...
# 786          5353
# 787          5050
# 788          5050
# 789          5050
# 790          5252
#
# [791 rows x 4 columns]

# %%
df["Points"] = pd.to_numeric(df["Points"], errors="coerce")
df["Points_dobble"] = pd.to_numeric(df["Points_dobble"], errors="coerce")
df
# Out:
#                                      UUID              Name  Points  \
# 0    aa3eaf74-6d9c-4859-b733-5a18a3b2f71b         afonso_rf   792.0
# 1    2d3d2dce-d353-4961-ad39-46723efe2100     mariicmartins  1375.0
# 2    ca95ef2a-5129-40f4-acbc-2ced25940032           tdlupus   421.0
# 3    65662aff-44d6-4f06-b9d9-07445c6e5943            kozat0  4063.0
# 4    98b960e7-6b7b-45b7-b7af-60bca40e04b9            gu1z17     0.0
# ..                                    ...               ...     ...
# 786  4a36c617-b018-436a-babc-4374461ab87b         null__var    53.0
# 787  403db18e-941e-4e63-ba23-e63c0515876a         lmadriles    50.0
# 788  c9bfbbf9-db90-45a7-a72c-4118140038f4  eduardo_cofferri    50.0
# 789  4caa2fb3-7ed2-436d-bc35-390feebfdebe          marmschu    50.0
# 790  000ff655-fa9f-4baa-a108-47f581ec52a1            cajuuh    52.0
#
#      Points_dobble   Lista
# 0         792792.0  [1, 2]
# 1       13751375.0  [1, 2]
# 2         421421.0  [1, 2]
# 3       40634063.0  [1, 2]
# 4              0.0  [1, 2]
# ..             ...     ...
# 786         5353.0  [1, 2]
# 787         5050.0  [1, 2]
# 788         5050.0  [1, 2]
# 789         5050.0  [1, 2]
# 790         5252.0  [1, 2]
#
# [791 rows x 5 columns]

# %%
df[["UUID", "Name"]].astype(str)
# Out:
#                                      UUID              Name
# 0    aa3eaf74-6d9c-4859-b733-5a18a3b2f71b         afonso_rf
# 1    2d3d2dce-d353-4961-ad39-46723efe2100     mariicmartins
# 2    ca95ef2a-5129-40f4-acbc-2ced25940032           tdlupus
# 3    65662aff-44d6-4f06-b9d9-07445c6e5943            kozat0
# 4    98b960e7-6b7b-45b7-b7af-60bca40e04b9            gu1z17
# ..                                    ...               ...
# 786  4a36c617-b018-436a-babc-4374461ab87b         null__var
# 787  403db18e-941e-4e63-ba23-e63c0515876a         lmadriles
# 788  c9bfbbf9-db90-45a7-a72c-4118140038f4  eduardo_cofferri
# 789  4caa2fb3-7ed2-436d-bc35-390feebfdebe          marmschu
# 790  000ff655-fa9f-4baa-a108-47f581ec52a1            cajuuh
#
# [791 rows x 2 columns]

# %%
df["Lista"] = [[ 1,2 ] for i in df.index ]
df
# Out:
#                                      UUID              Name  Points  \
# 0    aa3eaf74-6d9c-4859-b733-5a18a3b2f71b         afonso_rf   792.0
# 1    2d3d2dce-d353-4961-ad39-46723efe2100     mariicmartins  1375.0
# 2    ca95ef2a-5129-40f4-acbc-2ced25940032           tdlupus   421.0
# 3    65662aff-44d6-4f06-b9d9-07445c6e5943            kozat0  4063.0
# 4    98b960e7-6b7b-45b7-b7af-60bca40e04b9            gu1z17     0.0
# ..                                    ...               ...     ...
# 786  4a36c617-b018-436a-babc-4374461ab87b         null__var    53.0
# 787  403db18e-941e-4e63-ba23-e63c0515876a         lmadriles    50.0
# 788  c9bfbbf9-db90-45a7-a72c-4118140038f4  eduardo_cofferri    50.0
# 789  4caa2fb3-7ed2-436d-bc35-390feebfdebe          marmschu    50.0
# 790  000ff655-fa9f-4baa-a108-47f581ec52a1            cajuuh    52.0
#
#      Points_dobble   Lista
# 0         792792.0  [1, 2]
# 1       13751375.0  [1, 2]
# 2         421421.0  [1, 2]
# 3       40634063.0  [1, 2]
# 4              0.0  [1, 2]
# ..             ...     ...
# 786         5353.0  [1, 2]
# 787         5050.0  [1, 2]
# 788         5050.0  [1, 2]
# 789         5050.0  [1, 2]
# 790         5252.0  [1, 2]
#
# [791 rows x 5 columns]

# %%
df.dtypes
# Out:
# UUID              object
# Name              object
# Points           float64
# Points_dobble    float64
# Lista             object
# dtype: object
